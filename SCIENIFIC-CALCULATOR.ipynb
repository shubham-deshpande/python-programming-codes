# %%
from easygui import *
import sys
import math
a1="ENTER THE NUMBER OF TERMS TO BE ADDED"
a2="ENTER THE NUMBERS TO BE ADDED"
s1="ENTER THE NUMBER OF TERMS TO BE SUBTRACTED"
s2="ENTER THE NUMBERS TO BE SUBTRACTED"
m1="ENTER THE NUMBER OF TERMS TO BE MULTIPLIED"
m2="ENTER THE NUMBERS TO BE MULTIPLIED"
d1="ENTER THE NUMBER OF TERMS TO BE DIVIDED"
d2="ENTER THE NUMBERS TO BE DIVIDED"
q="DO YOU WANT TO CONTINUE YOUR CALCULATION WITH THIS ANSWER?" 
m="CHOOSE THE DESIRED OPERATION TO BE PERFORMED"
t="SCIENTIFIC CALCULATOR"
n="ENTER THE TYPE OF EQUATION"
c1=["Ax+By=C","Ax+By+Cz=D"]
c=["+","-","x","/","LOG","SIN","COS","TAN","SIN INV","COS INV","TAN INV"]
cm=["+","-","x","/","LOG","SIN","COS","TAN","SIN INV","COS INV","TAN INV","EQN","POLAR","RECTANGULAR"]
a3=a4=a5=b3=b4=b5=c3=c4=c5=d3=d4=d5=""
mul1=1
while 1:
    msgbox("WELCOME TO SCIENTIFIC CALCULATOR\n\n\nHOPE YOU ENJOY OUR CREATION  : )")
    b=buttonbox(m,t,cm)
    if b=="+":
        e=enterbox(a1,t)
        sum=0
        y=float(e)
        while y>0:
            e1=enterbox(a2,t)
            sum+=float(e1)
            y-=1
        msgbox("SUM = "+str(sum))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                e=enterbox(a1,t)
                sum1=float(sum)
                y=float(e)
                while y>0:
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                e=enterbox(s1,t)
                sub1=float(sum)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(sum)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
                if y==0:
                    msgbox("ANSWER = "+str(sum))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(sum)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(sum))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(sum))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(sum))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(sum))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(sum))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(sum))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(sum))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)
    elif b=="-":
        e=enterbox(s1,t)
        e1=enterbox(s2,t)
        sub=float(e1)
        y=float(e)
        while y>1:
            e1=enterbox(s2,t)
            sub-=float(e1)
            y-=1
        msgbox("ANSWER = "+str(sub))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                e=enterbox(a1,t)
                sum1=float(sub)
                y=float(e)
                while y>0:
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                e=enterbox(s1,t)
                sub1=float(sub)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO BE SUBTRACTED"
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                m1="ENTER THE NUMBER OF TERMS TO MULTIPLY"
                e=enterbox(m1,t)
                mul1=float(sub)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO BE MULTIPLIED"
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                m1="ENTER THE NUMBER OF TERMS TO BE DIVIDED"
                e=enterbox(d1,t)
                div1=float(sub)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO BE DIVIDED"
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(sub))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(sub))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(sub))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(sub))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(sub))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(sub))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(sub))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)        
    elif b=="x":
        m1="ENTER THE NUMBER OF TERMS TO MULTIPLY"
        e=enterbox(m1,t)
        mul=1
        y=float(e)
        while y>0:
            m2="ENTER THE NUMBERS TO BE MULTIPLIED"
            e1=enterbox(m2,t)
            mul*=float(e1)
            y-=1
        msgbox("ANSWER = "+str(mul))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                m1="ENTER THE NUMBER OF TERMS TO BE ADDED"
                e=enterbox(a1,t)
                sum1=float(mul)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO BE ADDED"
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m3="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(mul)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBER TO BE SUBTRACTED"
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                m1="ENTER THE NUMBER OF TERMS TO MULTIPLY"
                e=enterbox(m1,t)
                mul1=float(mul)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO BE MULTIPLIED"
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(mul)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(mul))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(mul))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(mul))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(mul))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(mul))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(mul))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(mul))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)
    elif b=="/":
        m1="ENTER THE NUMBER OF TERMS TO DIVIDE"
        e=enterbox(d1,t)
        m2="ENTER THE NUMBERS TO DIVIDE"
        e1=enterbox(d2,t)
        div=float(e1)
        y=float(e)
        while y>1:
            e1=enterbox(d2,t)
            div/=float(e1)
            y-=1
        msgbox("ANSWER = "+str(div))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                e=enterbox(a1,t)
                sum1=float(div)
                y=float(e)
                while y>0:
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m3="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(div)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(div)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(div)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(div))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(div))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(div))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(div))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(div))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(div))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(div))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)
    elif b=="LOG":
        m1="ENTER THE NUMBER TO FIND IT'S LOGARITHM"
        e=enterbox(m1,t)
        log=math.log(float(e))
        msgbox("ANSWER = "+str(log))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                e=enterbox(a1,t)
                sum1=float(log)
                y=float(e)
                while y>0:
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m3="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(log)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(log)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(log)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(log))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(log))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(log))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(log))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(log))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(log))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(log))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)
        
    elif b=="SIN":
        m1="ENTER THE NUMBER TO FIND IT'S SINE IN DEGREES"
        e=enterbox(m1,t)
        x=math.radians(float(e))
        sin=math.sin(float(x))
        msgbox("ANSWER = "+str(sin))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                e=enterbox(a1,t)
                sum1=float(sin)
                y=float(e)
                while y>0:
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m3="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(sin)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(sin)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(sin)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(sin))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(sin))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(sin))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(sin))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(sin))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(sin))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(sin))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)
    elif b=="COS":
        m1="ENTER THE NUMBER TO FIND IT'S COSINE IN DEGREES"
        e=enterbox(m1,t)
        x=math.radians(float(e))
        cos=math.cos(float(x))
        msgbox("ANSWER = "+str(cos))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                e=enterbox(a1,t)
                sum1=float(cos)
                y=float(e)
                while y>0:
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m3="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(cos)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(cos)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(cos)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(cos))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(cos))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(cos))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(cos))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(cos))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(cos))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(cos))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)        
    elif b=="TAN":
        m1="ENTER THE NUMBER TO FIND IT'S TANGENT IN DEGREES"
        e=enterbox(m1,t)
        x=math.radians(float(e))
        tan=math.tan(float(x))
        msgbox("ANSWER = "+str(tan))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                m1="ENTER THE NUMBER OF TERMS TO ADD"
                e=enterbox(a1,t)
                sum1=float(tan)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO ADD"
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m1="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(tan))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(tan))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(tan))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(tan))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)
    elif b=="SIN INV":
        m1="ENTER THE VALUE TO FIND IT'S SINE INVERSE"
        e=enterbox(m1,t)
        x=math.asin(float(e))
        y=math.degrees(float(x))
        msgbox("ANSWER = "+str(y))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                m1="ENTER THE NUMBER OF TERMS TO ADD"
                e=enterbox(a1,t)
                sum1=float(tan)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO ADD"
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m1="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(tan))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(tan))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(tan))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(tan))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)        
    elif b=="COS INV":
        m1="ENTER THE VALUE TO FIND IT'S COSINE INVERSE"
        e=enterbox(m1,t)
        x=math.acos(float(e))
        y=math.degrees(float(x))
        msgbox("ANSWER = "+str(y))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                m1="ENTER THE NUMBER OF TERMS TO ADD"
                e=enterbox(a1,t)
                sum1=float(tan)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO ADD"
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m1="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(tan))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(tan))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(tan))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(tan))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
        else:
            sys.exit(0)        
    elif b=="TAN INV":
        m1="ENTER THE VALUE TO FIND IT'S TANGENT INVERSE"
        e=enterbox(m1,t)
        x=math.atan(float(e))
        y=math.degrees(float(x))
        msgbox("ANSWER = "+str(y))
        if ccbox(q,t):
            b=buttonbox(m,t,c)
            if b=="+":
                m1="ENTER THE NUMBER OF TERMS TO ADD"
                e=enterbox(a1,t)
                sum1=float(tan)
                y=float(e)
                while y>0:
                    m2="ENTER THE NUMBERS TO ADD"
                    e1=enterbox(a2,t)
                    sum1+=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sum1))
            elif b=="-":
                m1="ENTER THE NUMBER OF TERMS TO SUBTRACT"
                e=enterbox(s1,t)
                sub1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(s2,t)
                    sub1-=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(sub1))
            elif b=="x":
                e=enterbox(m1,t)
                mul1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(m2,t)
                    mul1*=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(mul1))
            elif b=="/":
                e=enterbox(d1,t)
                div1=float(tan)
                y=float(e)
                while y>0:
                    e1=enterbox(d2,t)
                    div1/=float(e1)
                    y-=1
                msgbox("ANSWER = "+str(div1))
            elif b=="LOG":
                log1=math.log(float(tan))
                msgbox("ANSWER = "+str(log1))
            elif b=="SIN":
                x=math.radians(float(tan))
                sin1=math.sin(float(x))
                msgbox("ANSWER = "+str(sin1))
            elif b=="COS":
                x=math.radians(float(tan))
                cos1=math.cos(float(x))
                msgbox("ANSWER = "+str(cos1))
            elif b=="TAN":
                x=math.radians(float(tan))
                tan1=math.tan(float(x))
                msgbox("ANSWER = "+str(tan1))
            elif b=="SIN INV":
                x=math.asin(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="COS INV":
                x=math.acos(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
            elif b=="TAN INV":
                x=math.atan(float(tan))
                y=math.degrees(float(x))
                msgbox("ANSWER = "+str(y))
    elif b=="EQN":
        b1=buttonbox(n,t,c1)
        if b1=="Ax+By=C":
            m="ENTER THE FIRST EQUATION"
            e=enterbox(m,t)
            l=len(e)
            i=0
            while i<l:
                if e[i]=="x":
                    x=i
                else:
                    pass
                if e[i]=="y":
                    y=i
                else:
                    pass
                if e[i]=="=":
                    z=i+1
                else:
                    pass
                i+=1
            i=1
            while i<z:
                if e[i]=="+":
                    minus=0
                    w=i+1
                elif e[i]=="-":
                    minus=1
                    w=i+1
                else:
                    pass
                i+=1
            if e[0]=="-":
                j=1
                while j<x:
                    a3+=e[j]
                    j+=1
                a3=int(a3)
                a3=-a3
            else:
                j=0
                while j<x:
                    a3+=e[j]
                    j+=1
                a3=int(a3)
            while w<y:
                b3+=e[w]
                w+=1
            if minus=="0":
                b3=int(b3)
            else:
                b3=int(b3)
                b3=-b3
            if e[z]=="-":
                z+=1
                while z<l:    
                    c3+=e[z]
                    z+=1
                c3=int(c3)
                c3=-c3
            else:
                while z<l:
                    c3+=e[z]
                    z+=1
                c3=int(c3)
            m="ENTER THE SECOND EQUATION"
            e=enterbox(m,t)
            l=len(e)
            i=0
            while i<l:
                if e[i]=="x":
                    x=i
                else:
                    pass
                if e[i]=="y":
                    y=i
                else:
                    pass
                if e[i]=="=":
                    z=i+1
                else:
                    pass
                i+=1
            i=1
            while i<z:
                if e[i]=="+":
                    minus=0
                    w=i+1
                elif e[i]=="-":
                    minus=1
                    w=i+1
                else:
                    pass
                i+=1
            if e[0]=="-":
                j=1
                while j<x:
                    a4+=e[j]
                    j+=1
                a4=int(a4)
                a4=-a4
            else:
                j=0
                while j<x:
                    a4+=e[j]
                    j+=1
                a4=int(a4)
            while w<y:
                b4+=e[w]
                w+=1
            if minus=="0":
                b4=int(b4)
            else:
                b4=int(b4)
                b4=-b4
            if e[z]=="-":
                z+=1
                while z<l:    
                    c4+=e[z]
                    z+=1
                c4=int(c4)
                c4=-c4
            else:
                while z<l:
                    c4+=e[z]
                    z+=1
                c4=int(c4)
            D=(int(a3)*int(b4))-(int(a4)*int(b3))
            D1=(int(c3)*int(b4))-(int(c4)*int(b3))
            D2=(int(a3)*int(c4))-(int(a4)*int(c3))
            X=float(D1)/float(D)
            Y=float(D2)/float(D)
            msgbox("X = "+str(X)+"\nY = "+str(Y))
        elif b1=="Ax+By+Cz=D":
            m="ENTER THE FIRST EQUATION"
            e=enterbox(m,t)
            l=len(e)
            i=0
            while i<l:
                if e[i]=="x":
                    x=i
                else:
                    pass
                if e[i]=="y":
                    y=i
                else:
                    pass
                if e[i]=="=":
                    z=i+1
                else:
                    pass
                if e[i]=="z":
                    g=i
                else:
                    pass
                i+=1
            i=1
            while i<y:
                if e[i]=="+":
                    minus=0
                    w=i+1
                elif e[i]=="-":
                    minus=1
                    w=i+1
                else:
                    pass
                i+=1
            k=w
            while k<g:
                if e[k]=="+":
                    mi=0
                    v=k+1
                elif e[k]=="-":
                    mi=1
                    v=k+1
                else:
                    pass
                k+=1
            if e[0]=="-":
                j=1
                while j<x:
                    a3+=e[j]
                    j+=1
                a3=int(a3)
                a3=-a3
            else:
                j=0
                while j<x:
                    a3+=e[j]
                    j+=1
                a3=int(a3)
            while w<y:
                b3+=e[w]
                w+=1
            if minus=="0":
                b3=int(b3)
            else:
                b3=int(b3)
                b3=-b3
            if e[z]=="-":
                z+=1
                while z<l:    
                    d3+=e[z]
                    z+=1
                d3=int(d3)
                d3=-d3
            else:
                while z<l:
                    d3+=e[z]
                    z+=1
                d3=int(d3)
            while v<g:
                c3+=e[v]
                v+=1
            if mi=="0":
                c3=int(c3)
            else:
                c3=int(c3)
                c3=-c3
            m="ENTER THE SECOND EQUATION"
            e=enterbox(m,t)
            l=len(e)
            i=0
            while i<l:
                if e[i]=="x":
                    x=i
                else:
                    pass
                if e[i]=="y":
                    y=i
                else:
                    pass
                if e[i]=="=":
                    z=i+1
                else:
                    pass
                if e[i]=="z":
                    g=i
                else:
                    pass
                i+=1
            i=1
            while i<y:
                if e[i]=="+":
                    minus=0
                    w=i+1
                elif e[i]=="-":
                    minus=1
                    w=i+1
                else:
                    pass
                i+=1
            k=w
            while k<g:
                if e[k]=="+":
                    mi=0
                    v=k+1
                elif e[k]=="-":
                    mi=1
                    v=k+1
                else:
                    pass
                k+=1
            if e[0]=="-":
                j=1
                while j<x:
                    a4+=e[j]
                    j+=1
                a4=int(a4)
                a4=-a4
            else:
                j=0
                while j<x:
                    a4+=e[j]
                    j+=1
                a4=int(a4)
            while w<y:
                b4+=e[w]
                w+=1
            if minus=="0":
                b4=int(b4)
            else:
                b4=int(b4)
                b4=-b4
            if e[z]=="-":
                z+=1
                while z<l:    
                    d4+=e[z]
                    z+=1
                d4=int(d4)
                d4=-d4
            else:
                while z<l:
                    d4+=e[z]
                    z+=1
                d4=int(d4)
            while v<g:
                c4+=e[v]
                v+=1
            if mi=="0":
                c4=int(c4)
            else:
                c4=int(c4)
                c4=-c4
            m="ENTER THE THIRD EQUATION"
            e=enterbox(m,t)
            l=len(e)
            i=0
            while i<l:
                if e[i]=="x":
                    x=i
                else:
                    pass
                if e[i]=="y":
                    y=i
                else:
                    pass
                if e[i]=="=":
                    z=i+1
                else:
                    pass
                if e[i]=="z":
                    g=i
                else:
                    pass
                i+=1
            i=1
            while i<y:
                if e[i]=="+":
                    minus=0
                    w=i+1
                elif e[i]=="-":
                    minus=1
                    w=i+1
                else:
                    pass
                i+=1
            k=w
            while k<g:
                if e[k]=="+":
                    mi=0
                    v=k+1
                elif e[k]=="-":
                    mi=1
                    v=k+1
                else:
                    pass
                k+=1
            if e[0]=="-":
                j=1
                while j<x:
                    a5+=e[j]
                    j+=1
                a5=int(a5)
                a5=-a5
            else:
                j=0
                while j<x:
                    a5+=e[j]
                    j+=1
                a5=int(a5)
            while w<y:
                b5+=e[w]
                w+=1
            if minus=="0":
                b5=int(b5)
            else:
                b5=int(b5)
                b5=-b5
            if e[z]=="-":
                z+=1
                while z<l:    
                    d5+=e[z]
                    z+=1
                d5=int(d5)
                d5=-d5
            else:
                while z<l:
                    d5+=e[z]
                    z+=1
                d5=int(d5)
            while v<g:
                c5+=e[v]
                v+=1
            if mi=="0":
                c5=int(c5)
            else:
                c5=int(c5)
                c5=-c5
            D=(a3*b4*c5)+(a4*b5*c3)+(a5*b3*c4)-(a5*b4*c3)-(a4*b3*c5)-(a3*b5*c4)
            D1=(d3*b4*c5)+(d4*b5*c3)+(d5*b3*c4)-(d5*b4*c3)-(d4*b3*c5)-(d3*b5*c4)
            D2=(a3*d4*c5)+(a4*d5*c3)+(a5*d3*c4)-(a5*d4*c3)-(a4*d3*c5)-(a3*d5*c4)
            D3=(a3*b4*d5)+(a4*b5*d3)+(a5*b3*d4)-(a5*b4*d3)-(a4*b3*d5)-(a3*b5*d4)
            X=float(D1)/float(D)
            Y=float(D2)/float(D)
            Z=float(D3)/float(D)
            msgbox("X = "+str(X)+"\nY = "+str(Y)+"\nZ = "+str(Z)) 
    elif b=="POLAR":
        o1="ENTER    X : "
        o2="ENTER    Y : "
        p1=enterbox(o1,t)
        p2=enterbox(o2,t)
        p1=float(p1)
        p2=float(p2)
        R=math.sqrt((p1*p1)+(p2*p2))
        p3=p2/p1
        p4=math.atan(p3)
        THETA=math.degrees(p4)
        msgbox("R = "+str(R)+"\nTHETA = "+str(THETA))
    elif b=="RECTANGULAR":
        s1="ENTER    R : "
        s2="ENTER THETA IN DEGREE'S : "
        s3=enterbox(s1,t)
        s4=enterbox(s2,t)
        s3=float(s3)
        s4=float(s4)
        s4=math.radians(s4)
        X=(s3*(math.cos(s4)))
        Y=(s3*(math.sin(s4)))
        msgbox("X = "+str(X)+"\nY = "+str(Y))
    else:
        sys.exit(0)
    sys.exit(0)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Shubham-pc\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2886: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
